# %% [markdown]
# <a href="https://colab.research.google.com/github/vitormendesvr/Desafio-1---Ci-ncia-de-Dados/blob/main/AluraStoreBr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %% [markdown]
# ### Relatório de Análise de Lojas para Decisão de Venda
#
# #### **Introdução**
# O presente relatório tem como objetivo analisar o desempenho de quatro lojas de e-commerce para recomendar qual delas deve ser vendida. Para tanto, consideramos uma série de fatores: faturamento total das lojas, categorias de produtos mais e menos vendidas, média das avaliações dos clientes, os produtos mais e menos vendidos, e o custo médio de frete de cada loja. A partir da análise desses dados, será possível justificar qual loja apresenta as melhores perspectivas e quais apresentam desafios que podem justificar sua venda.
#
# #### **Desenvolvimento**
#
# 1. **Faturamento Total das Lojas**
#    O faturamento total das lojas é um indicador importante da saúde financeira de cada uma. Abaixo estão os valores de faturamento das lojas:
#      - Loja 1: **R$ 1.534.509,12**
#      - Loja 2: **R$ 1.488.459,06**
#      - Loja 3: **R$ 1.464.025,03**
#      - Loja 4: **R$ 1.384.497,58**
#
#    Com base nesses números, a **Loja 1** se destaca com o maior faturamento, seguida pela **Loja 2**. A **Loja 4** apresenta o menor faturamento, o que pode indicar uma performance financeira abaixo das demais.
#
#
# 2. **Categorias de Produtos Mais e Menos Vendidas**
#    As categorias de produtos vendidas em cada loja apresentam variações em termos de popularidade, refletindo as preferências dos consumidores. As lojas com categorias bem vendidas possuem um potencial maior de atrair clientes.
#
#      **Categorias mais vendidas**:
#      - Em todas as lojas, a **categoria de móveis** é a mais vendida.
#      - Loja 1: Móveis (465 unidades)
#      - Loja 2: Móveis (442 unidades)
#      - Loja 3: Móveis (499 unidades)
#      - Loja 4: Móveis (480 unidades)
#
#      Embora todas as lojas se destaquem com vendas de móveis, é possível notar que a **Loja 3** possui a maior venda dessa categoria, o que pode indicar uma preferência por seus produtos móveis.
#
#
# 3. **Média das Avaliações dos Clientes**
#    A satisfação dos clientes é crucial para o sucesso a longo prazo de uma loja. A média das avaliações dos clientes é um bom indicativo da qualidade do serviço e dos produtos oferecidos.
#      - Loja 1: **3.98**
#      - Loja 2: **4.04**
#      - Loja 3: **4.05**
#      - Loja 4: **4.0**
#
#    A **Loja 3** apresenta a melhor média de avaliações (4.05), o que sugere uma experiência do cliente superior. A **Loja 1**, apesar de ter um bom desempenho financeiro, apresenta uma avaliação um pouco mais baixa, o que pode ser um ponto de atenção.
#
#    **Gráfico 3: Média de Avaliações dos Clientes por Loja**
#    (Gráfico comparativo das avaliações médias)
#
# 4. **Produtos Mais e Menos Vendidos**
#    A análise dos produtos mais vendidos ajuda a entender quais itens têm maior apelo entre os consumidores.
#
#      - **Loja 1**: O produto mais vendido foi o **Micro-ondas** (60 unidades).
#      - **Loja 2**: O produto mais vendido foi **Iniciando em Programação** (65 unidades).
#      - **Loja 3**: O produto mais vendido foi o **Kit Banquetas** (57 unidades).
#      - **Loja 4**: O produto mais vendido foi a **Cama Box** (62 unidades).
#
#    Ao considerar os produtos mais vendidos, a **Loja 2** se destaca com o maior número de vendas em seu item mais popular. Além disso, a **Loja 4** tem uma boa distribuição entre seus produtos mais vendidos.
#
#
# 5. **Custo Médio de Frete**
#    O custo de frete pode influenciar diretamente na decisão de compra dos consumidores. Os custos médios de frete por loja são:
#      - Loja 1: **R$ 34.69**
#      - Loja 2: **R$ 33.62**
#      - Loja 3: **R$ 33.07**
#      - Loja 4: **R$ 31.28**
#
#    A **Loja 4** apresenta o menor custo médio de frete, o que pode ser um ponto positivo para a experiência do cliente, uma vez que o custo de frete mais baixo tende a atrair mais compradores.
#
#
# #### **Conclusão**
# Após a análise dos dados, a recomendação é que o **Senhor João** considere vender a **Loja 4**. A principal justificativa para essa recomendação é a combinação de fatores que indicam desafios para o crescimento da loja:
#
# - **Faturamento**: A **Loja 4** possui o menor faturamento entre as lojas, o que pode indicar uma performance inferior em termos de vendas.
# - **Avaliações**: Embora a média de avaliações da **Loja 4** seja razoável, ela está abaixo da **Loja 3**, que se destaca neste quesito.
# - **Produtos**: A Loja 4 não se destaca com produtos de grande apelo, o que pode indicar dificuldades em atrair mais clientes.
# - **Frete**: Apesar de ter o frete mais baixo, o que é um ponto positivo, isso não parece ser suficiente para compensar os outros fatores negativos.
#
# A **Loja 3** apresenta o melhor desempenho geral, com um bom faturamento, boas avaliações dos clientes, e produtos bem vendidos. Portanto, a **Loja 3** é a mais promissora para manter, enquanto a **Loja 4** deve ser vendida, considerando seu desempenho inferior.
#
# ---

# %%
faturamentoloja1 = loja.Preço.sum()
faturamentoloja2 = loja2.Preço.sum()
faturamentoloja3 = loja3.Preço.sum()
faturamentoloja4 = loja4.Preço.sum()

def formatar_reais(valor):
    return f'R$ {valor:,.2f}'.replace(',', 'v').replace('.', ',').replace('v', '.')

print(f'O faturamento da loja 1 é {formatar_reais(faturamentoloja1)}')
print(f'O faturamento da loja 2 é {formatar_reais(faturamentoloja2)}')
print(f'O faturamento da loja 3 é {formatar_reais(faturamentoloja3)}')
print(f'O faturamento da loja 4 é {formatar_reais(faturamentoloja4)}')
# Out:
# O faturamento da loja 1 é R$ 1.534.509,12
# O faturamento da loja 2 é R$ 1.488.459,06
# O faturamento da loja 3 é R$ 1.464.025,03
# O faturamento da loja 4 é R$ 1.384.497,58

# %% [markdown]
# # 2. Vendas por Categoria

# %%
dados_loja = loja[['Categoria do Produto', 'Produto']]
agrupado = dados_loja.groupby('Categoria do Produto').size()
print(f'A categoria mais vendida da loja 1 é: {agrupado.idxmax()}')
agrupado_ordenado = agrupado.sort_values(ascending=False)
print(f'As categorias mais vendidas da loja 1 são: {agrupado_ordenado}')

dados_loja2 = loja2[['Categoria do Produto', 'Produto']]
agrupado2 = dados_loja2.groupby('Categoria do Produto').size()
print(f'A categoria mais vendida da loja 2 é: {agrupado2.idxmax()}')
agrupado_ordenado2 = agrupado2.sort_values(ascending=False)
print(f'As categorias mais vendidas da loja 2 são: {agrupado_ordenado2}')

dados_loja3 = loja3[['Categoria do Produto', 'Produto']]
agrupado3 = dados_loja3.groupby('Categoria do Produto').size()
print(f'A categoria mais vendida da loja 3 é: {agrupado3.idxmax()}')
agrupado_ordenado3 = agrupado3.sort_values(ascending=False)
print(f'As categorias mais vendidas da loja 3 são: {agrupado_ordenado3}')

dados_loja4 = loja4[['Categoria do Produto', 'Produto']]
agrupado4 = dados_loja4.groupby('Categoria do Produto').size()
print(f'A categoria mais vendida da loja 4 é: {agrupado4.idxmax()}')
agrupado_ordenado4 = agrupado4.sort_values(ascending=False)
print(f'As categorias mais vendidas da loja 4 são: {agrupado_ordenado4}')
# Out:
# A categoria mais vendida da loja 1 é: moveis
# As categorias mais vendidas da loja 1 são: Categoria do Produto
# moveis                   465
# eletronicos              448
# brinquedos               324
# eletrodomesticos         312
# esporte e lazer          284
# instrumentos musicais    182
# livros                   173
# utilidades domesticas    171
# dtype: int64
# A categoria mais vendida da loja 2 é: moveis
# As categorias mais vendidas da loja 2 são: Categoria do Produto
# moveis                   442
# eletronicos              422
# brinquedos               313
# eletrodomesticos         305
# esporte e lazer          275
# instrumentos musicais    224
# livros                   197
# utilidades domesticas    181
# dtype: int64
# A categoria mais vendida da loja 3 é: moveis
# As categorias mais vendidas da loja 3 são: Categoria do Produto
# moveis                   499
# eletronicos              451
# brinquedos               315
# eletrodomesticos         278
# ...

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
soma_avaliacao = sum(loja['Avaliação da compra'])
print(f'A média de avaliação da loja 1 é {round(soma_avaliacao/len(loja), 2)}')

soma_avaliacao2 = sum(loja2['Avaliação da compra'])
print(f'A média de avaliação da loja 2 é {round(soma_avaliacao2/len(loja2), 2)}')

soma_avaliacao3 = sum(loja3['Avaliação da compra'])
print(f'A média de avaliação da loja 3 é {round(soma_avaliacao3/len(loja3),2)}')


soma_avaliacao4 = sum(loja4['Avaliação da compra'])
print(f'A média de avaliação da loja 4 é {round(soma_avaliacao4/len(loja4), 2)}')
# Out:
# A média de avaliação da loja 1 é 3.98
# A média de avaliação da loja 2 é 4.04
# A média de avaliação da loja 3 é 4.05
# A média de avaliação da loja 4 é 4.0

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
print(loja.columns)
# Out:
# Index(['Produto', 'Categoria do Produto', 'Preço', 'Frete', 'Data da Compra',
#        'Vendedor', 'Local da compra', 'Avaliação da compra',
#        'Tipo de pagamento', 'Quantidade de parcelas', 'lat', 'lon'],
#       dtype='object')

# %%
def produtos_destaque(df, nome_loja='Loja'):
    vendas = (
        df['Produto']
        .value_counts()
        .reset_index()
    )

    top5 = vendas.head(5)
    bottom5 = vendas.tail(5)

    print(f'\nTop 5 mais vendidos - {nome_loja}')
    print(top5)

    print(f'\nBottom 5 menos vendidos - {nome_loja}')
    print(bottom5)

produtos_destaque(loja, 'Loja 1')
produtos_destaque(loja2, 'Loja 2')
produtos_destaque(loja3, 'Loja 3')
produtos_destaque(loja4, 'Loja 4')
# Out:
# Top 5 mais vendidos - Loja 1
#               Produto  count
# 0         Micro-ondas     60
# 1       TV Led UHD 4K     60
# 2       Guarda roupas     60
# 3  Secadora de roupas     58
# 4              Cômoda     56
#
# Bottom 5 menos vendidos - Loja 1
#                         Produto  count
# 46  Ciência de dados com python     39
# 47                     Pandeiro     36
# 48            Panela de pressão     35
# 49                      Headset     33
# 50                 Celular ABXY     33
#
# Top 5 mais vendidos - Loja 2
#                     Produto  count
# 0  Iniciando em programação     65
# 1               Micro-ondas     62
# 2                   Bateria     61
# 3                    Violão     58
# 4                  Pandeiro     58
#
# Bottom 5 menos vendidos - Loja 2
#               Produto  count
# 46     Fone de ouvido     37
# 47           Poltrona     35
# 48     Mesa de jantar     34
# 49         Impressora     34
# 50  Jogo de tabuleiro     32
#
# ...

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
def calcular_frete_medio(df, nome_loja='Loja'):
    media = df['Frete'].mean()
    print(f'Custo médio de frete - {nome_loja}: R$ {media:.2f}')
calcular_frete_medio(loja, 'Loja 1')
calcular_frete_medio(loja2, 'Loja 2')
calcular_frete_medio(loja3, 'Loja 3')
calcular_frete_medio(loja4, 'Loja 4')
# Out:
# Custo médio de frete - Loja 1: R$ 34.69
# Custo médio de frete - Loja 2: R$ 33.62
# Custo médio de frete - Loja 3: R$ 33.07
# Custo médio de frete - Loja 4: R$ 31.28

# %%
import matplotlib.pyplot as plt

# %%
top_produtos = loja['Produto'].value_counts().head(10)

plt.figure(figsize=(10,6))
top_produtos.plot(kind='bar', color='royalblue')
plt.title('🛍️ Loja 1- Top 10 Produtos Mais Vendidos')
plt.xlabel('Produto')
plt.ylabel('Quantidade Vendida')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

top_produtos2 = loja2['Produto'].value_counts().head(10)

plt.figure(figsize=(10,6))
top_produtos2.plot(kind='bar', color='royalblue')
plt.title('🛍️ Loja 2 - Top 10 Produtos Mais Vendidos')
plt.xlabel('Produto')
plt.ylabel('Quantidade Vendida')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

top_produtos3 = loja3['Produto'].value_counts().head(10)

plt.figure(figsize=(10,6))
top_produtos3.plot(kind='bar', color='royalblue')
plt.title('🛍️ Loja 3 - Top 10 Produtos Mais Vendidos')
plt.xlabel('Produto')
plt.ylabel('Quantidade Vendida')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

top_produtos4 = loja4['Produto'].value_counts().head(10)

plt.figure(figsize=(10,6))
top_produtos4.plot(kind='bar', color='royalblue')
plt.title('🛍️ Loja 4 - Top 10 Produtos Mais Vendidos')
plt.xlabel('Produto')
plt.ylabel('Quantidade Vendida')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-20-4fab9e948b0e>:9: UserWarning: Glyph 128717 (\N{SHOPPING BAGS}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128717 (\N{SHOPPING BAGS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# <ipython-input-20-4fab9e948b0e>:20: UserWarning: Glyph 128717 (\N{SHOPPING BAGS}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128717 (\N{SHOPPING BAGS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# <ipython-input-20-4fab9e948b0e>:31: UserWarning: Glyph 128717 (\N{SHOPPING BAGS}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128717 (\N{SHOPPING BAGS}) missing from font(s) DejaVu Sans.
# ...

# %%
fig, axes = plt.subplots(2, 2, figsize=(14,12), sharey=True)

loja['Categoria do Produto'].value_counts().plot(kind='bar', ax=axes[0, 0], color='mediumseagreen')
axes[0, 0].set_title('🏪 Categorias - Loja 1')
axes[0, 0].set_xlabel('Categoria')
axes[0, 0].set_ylabel('Quantidade de Vendas')
axes[0, 0].tick_params(axis='x', rotation=45)

loja2['Categoria do Produto'].value_counts().plot(kind='bar', ax=axes[0, 1], color='tomato')
axes[0, 1].set_title('🏬 Categorias - Loja 2')
axes[0, 1].set_xlabel('Categoria')
axes[0, 1].tick_params(axis='x', rotation=45)

loja3['Categoria do Produto'].value_counts().plot(kind='bar', ax=axes[1, 0], color='mediumseagreen')
axes[1, 0].set_title('🏢 Categorias - Loja 3')
axes[1, 0].set_xlabel('Categoria')
axes[1, 0].tick_params(axis='x', rotation=45)

loja4['Categoria do Produto'].value_counts().plot(kind='bar', ax=axes[1, 1], color='tomato')
axes[1, 1].set_title('🏥 Categorias - Loja 4')
axes[1, 1].set_xlabel('Categoria')
axes[1, 1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-18-543d2809942b>:24: UserWarning: Glyph 127978 (\N{CONVENIENCE STORE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-18-543d2809942b>:24: UserWarning: Glyph 127980 (\N{DEPARTMENT STORE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-18-543d2809942b>:24: UserWarning: Glyph 127970 (\N{OFFICE BUILDING}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-18-543d2809942b>:24: UserWarning: Glyph 127973 (\N{HOSPITAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127978 (\N{CONVENIENCE STORE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127980 (\N{DEPARTMENT STORE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
media_fretes = {
    'Loja 1': loja['Frete'].mean(),
    'Loja 2': loja2['Frete'].mean(),
    'Loja 3': loja3['Frete'].mean(),
    'Loja 4': loja4['Frete'].mean()
}


plt.figure(figsize=(8,5))
plt.bar(media_fretes.keys(), media_fretes.values(), color='darkorange')
plt.title('📦 Custo Médio de Frete por Loja')
plt.ylabel('Valor Médio (R$)')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-24-80899277a7ca>:13: UserWarning: Glyph 128230 (\N{PACKAGE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
